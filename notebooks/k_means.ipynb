# %%
import numpy as np
from src import clustering
import matplotlib.pyplot as plt

# %%
SIZE = 100

X_1 = np.random.normal(100, 10, size=(SIZE,1))
X_2 = np.random.normal(100, 2, size=(SIZE, 1))

X_12 = np.random.normal(50, 1, size=(SIZE,1))
X_22 = np.random.normal(50, 2, size=(SIZE, 1))

X_1 = np.concatenate([X_1,X_12])
X_2 = np.concatenate([X_2,X_22])

data = np.column_stack([X_1,X_2])
ks = clustering.assign_k(data, 2)

# %%
coids = np.array([i for i in clustering.get_centroids(data, ks).values()])

# %%
coids
# Out:
# array([[77.94021964, 76.5258939 ],
#        [73.32095155, 72.86596357]])

# %%
plt.scatter(coids[:,0],coids[:,1],marker='*')
plt.scatter(x=data[:,0],y=data[:,1],c=ks)
